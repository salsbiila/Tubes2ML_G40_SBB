# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Load Dataset

# %%
print("Loading datasets...")
train_df = pd.read_csv('data/train.csv')
valid_df = pd.read_csv('data/valid.csv')
test_df = pd.read_csv('data/test.csv')

print(f"Train data shape: {train_df.shape}")
print(f"Validation data shape: {valid_df.shape}")
print(f"Test data shape: {test_df.shape}")
# Out:
# Loading datasets...
# Train data shape: (500, 3)
# Validation data shape: (100, 3)
# Test data shape: (400, 3)

# %%
print("\nSample train data:")
print(train_df.head())

print("\nLabel distribution in train data:")
print(train_df['label'].value_counts())
# Out:
# Sample train data:
#     id                                               text     label
# 0  219  Nikmati cicilan 0% hingga 12 bulan untuk pemes...   neutral
# 1  209  Kue-kue yang disajikan bikin saya bernostalgia...  positive
# 2  436               Ibu pernah bekerja di grab indonesia   neutral
# 3  394  Paling suka banget makan siang di sini ayam sa...  positive
# 4  592                    Pelayanan bus DAMRI sangat baik  positive
#
# Label distribution in train data:
# negative    192
# positive    189
# neutral     119
# Name: label, dtype: int64

# %% [markdown]
# ## Text Preprocessing

# %%
MAX_VOCAB_SIZE = 10000
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 128

# %%
text_vectorizer = tf.keras.layers.TextVectorization(
    max_tokens=MAX_VOCAB_SIZE,
    output_sequence_length=MAX_SEQUENCE_LENGTH,
    output_mode='int'
)
text_vectorizer.adapt(train_df['text'].values)

# %%
X_train = text_vectorizer(train_df['text'].values).numpy()
X_valid = text_vectorizer(valid_df['text'].values).numpy()
X_test = text_vectorizer(test_df['text'].values).numpy()

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['label'])
y_valid = label_encoder.transform(valid_df['label'])
y_test = label_encoder.transform(test_df['label'])

num_classes = len(label_encoder.classes_)
print(f"Number of classes: {num_classes}")
print(f"Classes: {label_encoder.classes_}")

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Number of classes: 3
# Classes: ['negative' 'neutral' 'positive']
# X_train shape: (500, 100)
# y_train shape: (500,)

# %% [markdown]
# ## Model Building Functions

# %%
def create_rnn_model(num_layers=1, units_per_layer=64, bidirectional=False, vocab_size=MAX_VOCAB_SIZE, 
                     embedding_dim=EMBEDDING_DIM, max_length=MAX_SEQUENCE_LENGTH, num_classes=num_classes):

    model = Sequential()
    
    # Embedding layer
    model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
    
    # RNN layers
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1) 
        
        if bidirectional:
            model.add(Bidirectional(SimpleRNN(units_per_layer, return_sequences=return_sequences)))
        else:
            model.add(SimpleRNN(units_per_layer, return_sequences=return_sequences))
        
        # Add dropout after each RNN layer
        model.add(Dropout(0.3))
    
    # Dense output layer
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
def train_model(model, X_train, y_train, X_valid, y_valid, epochs=20, batch_size=32):

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    
    return history

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    macro_f1 = f1_score(y_test, y_pred_classes, average='macro')
    
    return macro_f1, y_pred_classes

# %%
def plot_training_history(histories, labels, title):

    plt.figure(figsize=(20, 15))
    
    # Training Loss
    plt.subplot(2, 2, 1)
    for history, label in zip(histories, labels):
        plt.plot(history.history['loss'], label=f'{label}', linewidth=2)
    plt.title(f'{title} - Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Training Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Loss
    plt.subplot(2, 2, 2)
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_loss'], label=f'{label}', linewidth=2, linestyle='--')
    plt.title(f'{title} - Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Training Accuracy
    plt.subplot(2, 2, 3)
    for history, label in zip(histories, labels):
        plt.plot(history.history['accuracy'], label=f'{label}', linewidth=2)
    plt.title(f'{title} - Training Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Training Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Accuracy
    plt.subplot(2, 2, 4)
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_accuracy'], label=f'{label}', linewidth=2, linestyle='--')
    plt.title(f'{title} - Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Experiment 1: Pengaruh Jumlah Layer RNN

# %%
layer_variations = [1, 3, 7]
layer_results = {}
layer_histories = []
layer_labels = []

for num_layers in layer_variations:
    print(f"\nTraining model with {num_layers} RNN layer(s)...")
    
    model = create_rnn_model(num_layers=num_layers, units_per_layer=64)
    print(f"Model summary for {num_layers} layer(s):")
    model.summary()
    

    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    layer_results[num_layers] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    layer_histories.append(history)
    layer_labels.append(f'{num_layers} Layer(s)')
    
    print(f"Macro F1-Score for {num_layers} layer(s): {macro_f1:.4f}")


plot_training_history(layer_histories, layer_labels, "Effect of Number of RNN Layers")
for num_layers in layer_variations:
    print(f"{num_layers} Layer(s): Macro F1-Score = {layer_results[num_layers]['macro_f1']:.4f}")
# Out:
# Training model with 1 RNN layer(s)...
# Model summary for 1 layer(s):
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 64)                12352
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 1,292,547
# Trainable params: 1,292,547
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 1s 32ms/step - loss: 1.0779 - accuracy: 0.4200 - val_loss: 1.0867 - val_accuracy: 0.3700
# Epoch 2/15
# 16/16 [==============================] - 0s 20ms/step - loss: 1.0410 - accuracy: 0.4560 - val_loss: 1.1829 - val_accuracy: 0.3400
# Epoch 3/15
# 16/16 [==============================] - 0s 24ms/step - loss: 0.9649 - accuracy: 0.5080 - val_loss: 1.1584 - val_accuracy: 0.3500
# Epoch 4/15
# 16/16 [==============================] - 0s 23ms/step - loss: 0.7776 - accuracy: 0.7020 - val_loss: 1.3378 - val_accuracy: 0.3700
# Epoch 5/15
# 16/16 [==============================] - 0s 24ms/step - loss: 0.6410 - accuracy: 0.7720 - val_loss: 1.3458 - val_accuracy: 0.3400
# Epoch 6/15
# 16/16 [==============================] - 0s 23ms/step - loss: 0.4489 - accuracy: 0.8640 - val_loss: 1.6674 - val_accuracy: 0.3200
# Epoch 7/15
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2746 - accuracy: 0.9240 - val_loss: 1.9402 - val_accuracy: 0.3400
# Epoch 8/15
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1901 - accuracy: 0.9580 - val_loss: 2.1646 - val_accuracy: 0.3300
# Epoch 9/15
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1550 - accuracy: 0.9620 - val_loss: 2.3906 - val_accuracy: 0.3400
# Epoch 10/15
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1654 - accuracy: 0.9720 - val_loss: 2.3841 - val_accuracy: 0.3400
# Epoch 11/15
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0989 - accuracy: 0.9880 - val_loss: 2.5189 - val_accuracy: 0.3300
# Epoch 12/15
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0606 - accuracy: 0.9900 - val_loss: 2.6141 - val_accuracy: 0.3300
# Epoch 13/15
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0379 - accuracy: 0.9980 - val_loss: 2.7496 - val_accuracy: 0.3200
# Epoch 14/15
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 2.8755 - val_accuracy: 0.3400
# Epoch 15/15
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 2.9942 - val_accuracy: 0.3400
# 13/13 [==============================] - 0s 4ms/step
# Macro F1-Score for 1 layer(s): 0.3375
#
# Training model with 3 RNN layer(s)...
# Model summary for 3 layer(s):
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_1 (SimpleRNN)    (None, 100, 64)           12352
#
#  dropout_1 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_2 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_3 (SimpleRNN)    (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,309,059
# Trainable params: 1,309,059
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 55ms/step - loss: 1.2740 - accuracy: 0.3620 - val_loss: 0.9821 - val_accuracy: 0.5400
# Epoch 2/15
# 16/16 [==============================] - 1s 36ms/step - loss: 1.1759 - accuracy: 0.4100 - val_loss: 1.0819 - val_accuracy: 0.5200
# Epoch 3/15
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0622 - accuracy: 0.4740 - val_loss: 1.0525 - val_accuracy: 0.5300
# Epoch 4/15
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0533 - accuracy: 0.4660 - val_loss: 0.9376 - val_accuracy: 0.5500
# Epoch 5/15
# 16/16 [==============================] - 1s 36ms/step - loss: 0.8737 - accuracy: 0.5960 - val_loss: 1.1389 - val_accuracy: 0.4800
# Epoch 6/15
# 16/16 [==============================] - 1s 36ms/step - loss: 0.6315 - accuracy: 0.7360 - val_loss: 1.1919 - val_accuracy: 0.5100
# Epoch 7/15
# 16/16 [==============================] - 1s 37ms/step - loss: 0.4772 - accuracy: 0.8100 - val_loss: 1.4130 - val_accuracy: 0.5400
# Epoch 8/15
# 16/16 [==============================] - 1s 37ms/step - loss: 0.2652 - accuracy: 0.9120 - val_loss: 1.5391 - val_accuracy: 0.5400
# Epoch 9/15
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1746 - accuracy: 0.9440 - val_loss: 1.5865 - val_accuracy: 0.5200
# Epoch 10/15
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1084 - accuracy: 0.9700 - val_loss: 1.7314 - val_accuracy: 0.5100
# Epoch 11/15
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0927 - accuracy: 0.9700 - val_loss: 1.7580 - val_accuracy: 0.5500
# Epoch 12/15
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0403 - accuracy: 0.9920 - val_loss: 1.9039 - val_accuracy: 0.5200
# Epoch 13/15
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 1.8137 - val_accuracy: 0.4800
# Epoch 14/15
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.9474 - val_accuracy: 0.5200
# Epoch 15/15
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.0703 - val_accuracy: 0.5200
# 13/13 [==============================] - 0s 8ms/step
# Macro F1-Score for 3 layer(s): 0.5539
#
# Training model with 7 RNN layer(s)...
# Model summary for 7 layer(s):
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_4 (SimpleRNN)    (None, 100, 64)           12352
#
#  dropout_4 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_5 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_5 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_6 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_6 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_7 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_7 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_8 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_8 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_9 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_9 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_10 (SimpleRNN)   (None, 64)                8256
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,342,083
# Trainable params: 1,342,083
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 5s 106ms/step - loss: 1.3848 - accuracy: 0.3220 - val_loss: 1.0955 - val_accuracy: 0.3900
# Epoch 2/15
# 16/16 [==============================] - 1s 68ms/step - loss: 1.3088 - accuracy: 0.3160 - val_loss: 1.1603 - val_accuracy: 0.3800
# Epoch 3/15
# 16/16 [==============================] - 1s 69ms/step - loss: 1.2202 - accuracy: 0.3880 - val_loss: 1.0803 - val_accuracy: 0.3800
# Epoch 4/15
# 16/16 [==============================] - 1s 68ms/step - loss: 1.2695 - accuracy: 0.3320 - val_loss: 1.1569 - val_accuracy: 0.3800
# Epoch 5/15
# 16/16 [==============================] - 1s 68ms/step - loss: 1.2295 - accuracy: 0.3820 - val_loss: 1.0986 - val_accuracy: 0.3800
# Epoch 6/15
# 16/16 [==============================] - 1s 76ms/step - loss: 1.2061 - accuracy: 0.3540 - val_loss: 1.1169 - val_accuracy: 0.3800
# Epoch 7/15
# 16/16 [==============================] - 1s 71ms/step - loss: 1.2541 - accuracy: 0.3600 - val_loss: 1.0830 - val_accuracy: 0.3800
# Epoch 8/15
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2073 - accuracy: 0.3640 - val_loss: 1.0870 - val_accuracy: 0.3800
# Epoch 9/15
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2618 - accuracy: 0.3380 - val_loss: 1.1115 - val_accuracy: 0.3800
# Epoch 10/15
# 16/16 [==============================] - 1s 66ms/step - loss: 1.2292 - accuracy: 0.3560 - val_loss: 1.0838 - val_accuracy: 0.4200
# Epoch 11/15
# 16/16 [==============================] - 1s 69ms/step - loss: 1.2083 - accuracy: 0.3460 - val_loss: 1.1056 - val_accuracy: 0.4400
# Epoch 12/15
# 16/16 [==============================] - 1s 67ms/step - loss: 1.1421 - accuracy: 0.3880 - val_loss: 1.1009 - val_accuracy: 0.2800
# Epoch 13/15
# 16/16 [==============================] - 1s 75ms/step - loss: 1.2516 - accuracy: 0.3020 - val_loss: 1.0859 - val_accuracy: 0.4300
# Epoch 14/15
# 16/16 [==============================] - 1s 75ms/step - loss: 1.2083 - accuracy: 0.3160 - val_loss: 1.0914 - val_accuracy: 0.3400
# Epoch 15/15
# 16/16 [==============================] - 1s 77ms/step - loss: 1.1466 - accuracy: 0.3860 - val_loss: 1.0732 - val_accuracy: 0.4500
# 13/13 [==============================] - 1s 18ms/step
# Macro F1-Score for 7 layer(s): 0.3081
# 1 Layer(s): Macro F1-Score = 0.3375
# 3 Layer(s): Macro F1-Score = 0.5539
# 7 Layer(s): Macro F1-Score = 0.3081

# %% [markdown]
# ## Experiment 2: Pengaruh Banyak Cell RNN per Layer

# %%
cell_variations = [32, 64, 128]
cell_results = {}
cell_histories = []
cell_labels = []

for num_cells in cell_variations:
    print(f"\nTraining model with {num_cells} cells per layer...")

    model = create_rnn_model(num_layers=2, units_per_layer=num_cells)
    print(f"Model summary for {num_cells} cells:")
    model.summary()
    
    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    cell_results[num_cells] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    cell_histories.append(history)
    cell_labels.append(f'{num_cells} Cells')
    
    print(f"Macro F1-Score for {num_cells} cells: {macro_f1:.4f}")

plot_training_history(cell_histories, cell_labels, "Effect of Number of RNN Cells per Layer")
for num_cells in cell_variations:
    print(f"{num_cells} Cells: Macro F1-Score = {cell_results[num_cells]['macro_f1']:.4f}")
# Out:
# Training model with 32 cells per layer...
# Model summary for 32 cells:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_11 (SimpleRNN)   (None, 100, 32)           5152
#
#  dropout_11 (Dropout)        (None, 100, 32)           0
#
#  simple_rnn_12 (SimpleRNN)   (None, 32)                2080
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_3 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1,287,331
# Trainable params: 1,287,331
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 44ms/step - loss: 1.1782 - accuracy: 0.3700 - val_loss: 1.0878 - val_accuracy: 0.3900
# Epoch 2/15
# 16/16 [==============================] - 0s 28ms/step - loss: 1.0437 - accuracy: 0.4280 - val_loss: 1.1793 - val_accuracy: 0.2900
# Epoch 3/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.7509 - accuracy: 0.7140 - val_loss: 1.3092 - val_accuracy: 0.3000
# Epoch 4/15
# 16/16 [==============================] - 1s 31ms/step - loss: 0.3822 - accuracy: 0.9260 - val_loss: 1.4310 - val_accuracy: 0.3400
# Epoch 5/15
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2031 - accuracy: 0.9780 - val_loss: 1.6119 - val_accuracy: 0.3600
# Epoch 6/15
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0904 - accuracy: 1.0000 - val_loss: 1.8003 - val_accuracy: 0.2800
# Epoch 7/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0564 - accuracy: 0.9980 - val_loss: 1.8358 - val_accuracy: 0.3600
# Epoch 8/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 1.9108 - val_accuracy: 0.3100
# Epoch 9/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 1.9542 - val_accuracy: 0.3300
# Epoch 10/15
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 2.0335 - val_accuracy: 0.3400
# Epoch 11/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 2.0053 - val_accuracy: 0.3500
# Epoch 12/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 2.0513 - val_accuracy: 0.3400
# Epoch 13/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.0829 - val_accuracy: 0.3500
# Epoch 14/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 2.0975 - val_accuracy: 0.3400
# Epoch 15/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 2.1558 - val_accuracy: 0.3500
# 13/13 [==============================] - 0s 5ms/step
# Macro F1-Score for 32 cells: 0.3559
#
# Training model with 64 cells per layer...
# Model summary for 64 cells:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_13 (SimpleRNN)   (None, 100, 64)           12352
#
#  dropout_13 (Dropout)        (None, 100, 64)           0
#
#  simple_rnn_14 (SimpleRNN)   (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_4 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,300,803
# Trainable params: 1,300,803
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 44ms/step - loss: 1.1675 - accuracy: 0.3420 - val_loss: 1.1385 - val_accuracy: 0.3300
# Epoch 2/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.9748 - accuracy: 0.5240 - val_loss: 1.2463 - val_accuracy: 0.4200
# Epoch 3/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6983 - accuracy: 0.7240 - val_loss: 1.3711 - val_accuracy: 0.3100
# Epoch 4/15
# 16/16 [==============================] - 1s 38ms/step - loss: 0.4214 - accuracy: 0.8580 - val_loss: 1.5464 - val_accuracy: 0.3100
# Epoch 5/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1933 - accuracy: 0.9440 - val_loss: 1.6831 - val_accuracy: 0.3500
# Epoch 6/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0938 - accuracy: 0.9900 - val_loss: 2.0497 - val_accuracy: 0.2900
# Epoch 7/15
# 16/16 [==============================] - 1s 47ms/step - loss: 0.0311 - accuracy: 0.9980 - val_loss: 2.0902 - val_accuracy: 0.3600
# Epoch 8/15
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 2.0806 - val_accuracy: 0.4200
# Epoch 9/15
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.2829 - val_accuracy: 0.3800
# Epoch 10/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 2.2795 - val_accuracy: 0.3800
# Epoch 11/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.2713 - val_accuracy: 0.3800
# Epoch 12/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.3866 - val_accuracy: 0.3600
# Epoch 13/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.3160 - val_accuracy: 0.3700
# Epoch 14/15
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4113 - val_accuracy: 0.3600
# Epoch 15/15
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.4553 - val_accuracy: 0.3700
# 13/13 [==============================] - 0s 6ms/step
# Macro F1-Score for 64 cells: 0.4042
#
# Training model with 128 cells per layer...
# Model summary for 128 cells:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_15 (SimpleRNN)   (None, 100, 128)          32896
#
#  dropout_15 (Dropout)        (None, 100, 128)          0
#
#  simple_rnn_16 (SimpleRNN)   (None, 128)               32896
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,346,179
# Trainable params: 1,346,179
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 56ms/step - loss: 1.1488 - accuracy: 0.3620 - val_loss: 1.1163 - val_accuracy: 0.3600
# Epoch 2/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.0259 - accuracy: 0.5020 - val_loss: 1.2785 - val_accuracy: 0.3900
# Epoch 3/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.1031 - accuracy: 0.4540 - val_loss: 1.3018 - val_accuracy: 0.4500
# Epoch 4/15
# 16/16 [==============================] - 1s 44ms/step - loss: 1.0636 - accuracy: 0.4880 - val_loss: 1.2775 - val_accuracy: 0.3600
# Epoch 5/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.2108 - accuracy: 0.4220 - val_loss: 1.1251 - val_accuracy: 0.4100
# Epoch 6/15
# 16/16 [==============================] - 1s 43ms/step - loss: 1.1972 - accuracy: 0.4200 - val_loss: 1.1355 - val_accuracy: 0.4700
# Epoch 7/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.1461 - accuracy: 0.4180 - val_loss: 1.0914 - val_accuracy: 0.4800
# Epoch 8/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.1468 - accuracy: 0.4440 - val_loss: 1.1110 - val_accuracy: 0.3800
# Epoch 9/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1667 - accuracy: 0.4040 - val_loss: 1.0916 - val_accuracy: 0.4800
# Epoch 10/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.1470 - accuracy: 0.4060 - val_loss: 1.0533 - val_accuracy: 0.4800
# Epoch 11/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1629 - accuracy: 0.4160 - val_loss: 1.0457 - val_accuracy: 0.5100
# Epoch 12/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1288 - accuracy: 0.4500 - val_loss: 1.0696 - val_accuracy: 0.5100
# Epoch 13/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1432 - accuracy: 0.4260 - val_loss: 1.0391 - val_accuracy: 0.5000
# Epoch 14/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.1316 - accuracy: 0.4420 - val_loss: 1.0830 - val_accuracy: 0.5000
# Epoch 15/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.1775 - accuracy: 0.3820 - val_loss: 1.0558 - val_accuracy: 0.5100
# 13/13 [==============================] - 0s 10ms/step
# Macro F1-Score for 128 cells: 0.3186
# 32 Cells: Macro F1-Score = 0.3559
# 64 Cells: Macro F1-Score = 0.4042
# 128 Cells: Macro F1-Score = 0.3186

# %% [markdown]
# ## Experiment 3: Pengaruh Jenis Layer RNN Berdasarkan Arah

# %%
direction_variations = [False, True] 
direction_labels_map = {False: 'Unidirectional', True: 'Bidirectional'}
direction_results = {}
direction_histories = []
direction_labels = []

for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    print(f"\nTraining {direction_name} RNN model...")
    
    model = create_rnn_model(num_layers=2, units_per_layer=64, bidirectional=bidirectional)
    print(f"Model summary for {direction_name} RNN:")
    model.summary()

    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    direction_results[bidirectional] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    direction_histories.append(history)
    direction_labels.append(direction_name)
    
    print(f"Macro F1-Score for {direction_name}: {macro_f1:.4f}")

plot_training_history(direction_histories, direction_labels, "Effect of RNN Direction")
for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    print(f"{direction_name}: Macro F1-Score = {direction_results[bidirectional]['macro_f1']:.4f}")
# Out:
# Training Unidirectional RNN model...
# Model summary for Unidirectional RNN:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_17 (SimpleRNN)   (None, 100, 64)           12352
#
#  dropout_17 (Dropout)        (None, 100, 64)           0
#
#  simple_rnn_18 (SimpleRNN)   (None, 64)                8256
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_6 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,300,803
# Trainable params: 1,300,803
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 41ms/step - loss: 1.1291 - accuracy: 0.3740 - val_loss: 1.0844 - val_accuracy: 0.4000
# Epoch 2/15
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0242 - accuracy: 0.4780 - val_loss: 1.0901 - val_accuracy: 0.4500
# Epoch 3/15
# 16/16 [==============================] - 0s 31ms/step - loss: 0.8256 - accuracy: 0.6400 - val_loss: 1.1675 - val_accuracy: 0.4000
# Epoch 4/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5333 - accuracy: 0.7940 - val_loss: 1.2716 - val_accuracy: 0.4800
# Epoch 5/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1941 - accuracy: 0.9620 - val_loss: 1.5548 - val_accuracy: 0.5000
# Epoch 6/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0865 - accuracy: 0.9900 - val_loss: 1.7613 - val_accuracy: 0.4700
# Epoch 7/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0373 - accuracy: 0.9980 - val_loss: 1.8708 - val_accuracy: 0.4700
# Epoch 8/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 1.9781 - val_accuracy: 0.5000
# Epoch 9/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 2.0583 - val_accuracy: 0.5200
# Epoch 10/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 2.0600 - val_accuracy: 0.5100
# Epoch 11/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 2.1160 - val_accuracy: 0.5200
# Epoch 12/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.1332 - val_accuracy: 0.5200
# Epoch 13/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.1743 - val_accuracy: 0.5200
# Epoch 14/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.2150 - val_accuracy: 0.5000
# Epoch 15/15
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.2187 - val_accuracy: 0.5300
# 13/13 [==============================] - 0s 6ms/step
# Macro F1-Score for Unidirectional: 0.4835
#
# Training Bidirectional RNN model...
# Model summary for Bidirectional RNN:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 100, 128)          1280000
#
#  bidirectional (Bidirectiona  (None, 100, 128)         24704
#  l)
#
#  dropout_19 (Dropout)        (None, 100, 128)          0
#
#  bidirectional_1 (Bidirectio  (None, 128)              24704
#  nal)
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,329,795
# Trainable params: 1,329,795
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 3s 74ms/step - loss: 1.1455 - accuracy: 0.3500 - val_loss: 1.0863 - val_accuracy: 0.3500
# Epoch 2/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.8325 - accuracy: 0.6220 - val_loss: 0.9852 - val_accuracy: 0.5700
# Epoch 3/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.4891 - accuracy: 0.8520 - val_loss: 1.0447 - val_accuracy: 0.5000
# Epoch 4/15
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1900 - accuracy: 0.9660 - val_loss: 1.0321 - val_accuracy: 0.5500
# Epoch 5/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0875 - accuracy: 0.9880 - val_loss: 1.2382 - val_accuracy: 0.5200
# Epoch 6/15
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 1.3321 - val_accuracy: 0.5600
# Epoch 7/15
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.2660 - val_accuracy: 0.5800
# Epoch 8/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.3439 - val_accuracy: 0.5700
# Epoch 9/15
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3524 - val_accuracy: 0.5700
# Epoch 10/15
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.3774 - val_accuracy: 0.5800
# Epoch 11/15
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.4001 - val_accuracy: 0.5600
# Epoch 12/15
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.4070 - val_accuracy: 0.5800
# Epoch 13/15
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3990 - val_accuracy: 0.5700
# Epoch 14/15
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4349 - val_accuracy: 0.5900
# Epoch 15/15
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.4395 - val_accuracy: 0.5800
# 13/13 [==============================] - 0s 11ms/step
# Macro F1-Score for Bidirectional: 0.4964
# Unidirectional: Macro F1-Score = 0.4835
# Bidirectional: Macro F1-Score = 0.4964

# %% [markdown]
# ## Summary

# %%
print("\n1. PENGARUH JUMLAH LAYER RNN:")
best_layers = max(layer_results.keys(), key=lambda x: layer_results[x]['macro_f1'])
for num_layers in layer_variations:
    f1_score = layer_results[num_layers]['macro_f1']
    print(f"   {num_layers} Layer(s): {f1_score:.4f}" + (" -- BEST" if num_layers == best_layers else ""))

print("\n2. PENGARUH BANYAK CELL RNN PER LAYER:")
best_cells = max(cell_results.keys(), key=lambda x: cell_results[x]['macro_f1'])
for num_cells in cell_variations:
    f1_score = cell_results[num_cells]['macro_f1']
    print(f"   {num_cells} Cells: {f1_score:.4f}" + (" -- BEST" if num_cells == best_cells else ""))

print("\n3. PENGARUH JENIS LAYER RNN BERDASARKAN ARAH:")
best_direction = max(direction_results.keys(), key=lambda x: direction_results[x]['macro_f1'])
for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    f1_score = direction_results[bidirectional]['macro_f1']
    print(f"   {direction_name}: {f1_score:.4f}" + (" -- BEST" if bidirectional == best_direction else ""))
# Out:
# 1. PENGARUH JUMLAH LAYER RNN:
#    1 Layer(s): 0.3375
#    3 Layer(s): 0.5539 -- BEST
#    7 Layer(s): 0.3081
#
# 2. PENGARUH BANYAK CELL RNN PER LAYER:
#    32 Cells: 0.3559
#    64 Cells: 0.4042 -- BEST
#    128 Cells: 0.3186
#
# 3. PENGARUH JENIS LAYER RNN BERDASARKAN ARAH:
#    Unidirectional: 0.4835
#    Bidirectional: 0.4964 -- BEST
