# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score, classification_report
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Load Dataset

# %%
print("Loading datasets...")
train_df = pd.read_csv('data/train.csv')
valid_df = pd.read_csv('data/valid.csv')
test_df = pd.read_csv('data/test.csv')

print(f"Train data shape: {train_df.shape}")
print(f"Validation data shape: {valid_df.shape}")
print(f"Test data shape: {test_df.shape}")
# Out:
# Loading datasets...
# Train data shape: (500, 3)
# Validation data shape: (100, 3)
# Test data shape: (400, 3)

# %%
print("\nSample train data:")
print(train_df.head())

print("\nLabel distribution in train data:")
print(train_df['label'].value_counts())
# Out:
# Sample train data:
#     id                                               text     label
# 0  219  Nikmati cicilan 0% hingga 12 bulan untuk pemes...   neutral
# 1  209  Kue-kue yang disajikan bikin saya bernostalgia...  positive
# 2  436               Ibu pernah bekerja di grab indonesia   neutral
# 3  394  Paling suka banget makan siang di sini ayam sa...  positive
# 4  592                    Pelayanan bus DAMRI sangat baik  positive
#
# Label distribution in train data:
# negative    192
# positive    189
# neutral     119
# Name: label, dtype: int64

# %% [markdown]
# ## Text Preprocessing

# %%
MAX_VOCAB_SIZE = 10000
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 128

# %%
text_vectorizer = tf.keras.layers.TextVectorization(
    max_tokens=MAX_VOCAB_SIZE,
    output_sequence_length=MAX_SEQUENCE_LENGTH,
    output_mode='int'
)
text_vectorizer.adapt(train_df['text'].values)

# %%
X_train = text_vectorizer(train_df['text'].values).numpy()
X_valid = text_vectorizer(valid_df['text'].values).numpy()
X_test = text_vectorizer(test_df['text'].values).numpy()

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['label'])
y_valid = label_encoder.transform(valid_df['label'])
y_test = label_encoder.transform(test_df['label'])

num_classes = len(label_encoder.classes_)
print(f"Number of classes: {num_classes}")
print(f"Classes: {label_encoder.classes_}")

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Number of classes: 3
# Classes: ['negative' 'neutral' 'positive']
# X_train shape: (500, 100)
# y_train shape: (500,)

# %% [markdown]
# ## Model Building Functions

# %%
def create_rnn_model(num_layers=1, units_per_layer=64, bidirectional=False, vocab_size=MAX_VOCAB_SIZE, 
                     embedding_dim=EMBEDDING_DIM, max_length=MAX_SEQUENCE_LENGTH, num_classes=num_classes):

    model = Sequential()
    
    # Embedding layer
    model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
    
    # RNN layers
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1) 
        
        if bidirectional:
            model.add(Bidirectional(SimpleRNN(units_per_layer, return_sequences=return_sequences)))
        else:
            model.add(SimpleRNN(units_per_layer, return_sequences=return_sequences))
        
        # Add dropout after each RNN layer
        model.add(Dropout(0.3))
    
    # Dense output layer
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
def train_model(model, X_train, y_train, X_valid, y_valid, epochs=20, batch_size=32):

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        epochs=epochs,
        batch_size=batch_size,
        verbose=1
    )
    
    return history

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    macro_f1 = f1_score(y_test, y_pred_classes, average='macro')
    
    return macro_f1, y_pred_classes

# %%
def plot_training_history(histories, labels, title):

    plt.figure(figsize=(20, 15))
    
    # Training Loss
    plt.subplot(2, 2, 1)
    for history, label in zip(histories, labels):
        plt.plot(history.history['loss'], label=f'{label}', linewidth=2)
    plt.title(f'{title} - Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Training Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Loss
    plt.subplot(2, 2, 2)
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_loss'], label=f'{label}', linewidth=2, linestyle='--')
    plt.title(f'{title} - Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Training Accuracy
    plt.subplot(2, 2, 3)
    for history, label in zip(histories, labels):
        plt.plot(history.history['accuracy'], label=f'{label}', linewidth=2)
    plt.title(f'{title} - Training Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Training Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Validation Accuracy
    plt.subplot(2, 2, 4)
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_accuracy'], label=f'{label}', linewidth=2, linestyle='--')
    plt.title(f'{title} - Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Experiment 1: Pengaruh Jumlah Layer RNN

# %%
layer_variations = [1, 3, 7]
layer_results = {}
layer_histories = []
layer_labels = []

for num_layers in layer_variations:
    print(f"\nTraining model with {num_layers} RNN layer(s)...")
    
    model = create_rnn_model(num_layers=num_layers, units_per_layer=64)
    print(f"Model summary for {num_layers} layer(s):")
    model.summary()
    

    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    layer_results[num_layers] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    layer_histories.append(history)
    layer_labels.append(f'{num_layers} Layer(s)')
    
    print(f"Macro F1-Score for {num_layers} layer(s): {macro_f1:.4f}")


plot_training_history(layer_histories, layer_labels, "Effect of Number of RNN Layers")
for num_layers in layer_variations:
    print(f"{num_layers} Layer(s): Macro F1-Score = {layer_results[num_layers]['macro_f1']:.4f}")
# Out:
# Training model with 1 RNN layer(s)...
# Model summary for 1 layer(s):
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 64)                12352
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 1,292,547
# Trainable params: 1,292,547
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 1s 39ms/step - loss: 1.0965 - accuracy: 0.3600 - val_loss: 1.0567 - val_accuracy: 0.4600
# Epoch 2/15
# 16/16 [==============================] - 0s 19ms/step - loss: 1.0187 - accuracy: 0.4860 - val_loss: 1.1686 - val_accuracy: 0.3200
# Epoch 3/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.8748 - accuracy: 0.6100 - val_loss: 1.1074 - val_accuracy: 0.4100
# Epoch 4/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.6870 - accuracy: 0.7620 - val_loss: 1.1936 - val_accuracy: 0.4200
# Epoch 5/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4139 - accuracy: 0.9000 - val_loss: 1.1579 - val_accuracy: 0.4800
# Epoch 6/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.2395 - accuracy: 0.9760 - val_loss: 1.2100 - val_accuracy: 0.4800
# Epoch 7/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1131 - accuracy: 1.0000 - val_loss: 1.3045 - val_accuracy: 0.5100
# Epoch 8/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 1.3506 - val_accuracy: 0.5100
# Epoch 9/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0418 - accuracy: 1.0000 - val_loss: 1.3701 - val_accuracy: 0.5300
# Epoch 10/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 1.4129 - val_accuracy: 0.5200
# Epoch 11/15
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.4616 - val_accuracy: 0.5000
# Epoch 12/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.4323 - val_accuracy: 0.5100
# Epoch 13/15
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.4588 - val_accuracy: 0.4900
# Epoch 14/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.4758 - val_accuracy: 0.5000
# Epoch 15/15
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.5030 - val_accuracy: 0.5000
# 13/13 [==============================] - 0s 4ms/step
# Macro F1-Score for 1 layer(s): 0.4092
#
# Training model with 3 RNN layer(s)...
# Model summary for 3 layer(s):
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_1 (SimpleRNN)    (None, 100, 64)           12352
#
#  dropout_1 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_2 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_3 (SimpleRNN)    (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,309,059
# Trainable params: 1,309,059
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 52ms/step - loss: 1.2687 - accuracy: 0.3720 - val_loss: 1.1100 - val_accuracy: 0.3800
# Epoch 2/15
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2304 - accuracy: 0.3720 - val_loss: 1.1154 - val_accuracy: 0.3000
# Epoch 3/15
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2458 - accuracy: 0.3740 - val_loss: 1.3590 - val_accuracy: 0.3200
# Epoch 4/15
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2032 - accuracy: 0.3820 - val_loss: 1.1654 - val_accuracy: 0.3300
# Epoch 5/15
# 16/16 [==============================] - 1s 35ms/step - loss: 1.2482 - accuracy: 0.3500 - val_loss: 1.1059 - val_accuracy: 0.3800
# Epoch 6/15
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2162 - accuracy: 0.3800 - val_loss: 1.0887 - val_accuracy: 0.4200
# Epoch 7/15
# 16/16 [==============================] - 1s 38ms/step - loss: 1.1024 - accuracy: 0.4440 - val_loss: 1.1090 - val_accuracy: 0.3800
# Epoch 8/15
# 16/16 [==============================] - 1s 36ms/step - loss: 1.1552 - accuracy: 0.4440 - val_loss: 1.2115 - val_accuracy: 0.3900
# Epoch 9/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.9887 - accuracy: 0.5380 - val_loss: 1.4149 - val_accuracy: 0.3200
# Epoch 10/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8874 - accuracy: 0.6020 - val_loss: 1.3708 - val_accuracy: 0.3800
# Epoch 11/15
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6249 - accuracy: 0.7620 - val_loss: 1.7211 - val_accuracy: 0.3900
# Epoch 12/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.4232 - accuracy: 0.8440 - val_loss: 2.2146 - val_accuracy: 0.4000
# Epoch 13/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3449 - accuracy: 0.8620 - val_loss: 2.0694 - val_accuracy: 0.4100
# Epoch 14/15
# 16/16 [==============================] - 1s 34ms/step - loss: 0.3630 - accuracy: 0.8700 - val_loss: 1.9146 - val_accuracy: 0.4200
# Epoch 15/15
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2239 - accuracy: 0.9200 - val_loss: 2.2090 - val_accuracy: 0.3500
# 13/13 [==============================] - 0s 8ms/step
# Macro F1-Score for 3 layer(s): 0.3571
#
# Training model with 7 RNN layer(s)...
# Model summary for 7 layer(s):
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_4 (SimpleRNN)    (None, 100, 64)           12352
#
#  dropout_4 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_5 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_5 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_6 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_6 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_7 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_7 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_8 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_8 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_9 (SimpleRNN)    (None, 100, 64)           8256
#
#  dropout_9 (Dropout)         (None, 100, 64)           0
#
#  simple_rnn_10 (SimpleRNN)   (None, 64)                8256
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,342,083
# Trainable params: 1,342,083
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 5s 109ms/step - loss: 1.4592 - accuracy: 0.3240 - val_loss: 1.1080 - val_accuracy: 0.3800
# Epoch 2/15
# 16/16 [==============================] - 1s 64ms/step - loss: 1.3109 - accuracy: 0.3580 - val_loss: 1.1590 - val_accuracy: 0.3800
# Epoch 3/15
# 16/16 [==============================] - 1s 67ms/step - loss: 1.3106 - accuracy: 0.3260 - val_loss: 1.0864 - val_accuracy: 0.3800
# Epoch 4/15
# 16/16 [==============================] - 1s 63ms/step - loss: 1.2704 - accuracy: 0.3500 - val_loss: 1.0927 - val_accuracy: 0.3800
# Epoch 5/15
# 16/16 [==============================] - 1s 65ms/step - loss: 1.2888 - accuracy: 0.3420 - val_loss: 1.0815 - val_accuracy: 0.3800
# Epoch 6/15
# 16/16 [==============================] - 1s 68ms/step - loss: 1.2991 - accuracy: 0.3440 - val_loss: 1.0830 - val_accuracy: 0.3800
# Epoch 7/15
# 16/16 [==============================] - 1s 63ms/step - loss: 1.2325 - accuracy: 0.3560 - val_loss: 1.0815 - val_accuracy: 0.3800
# Epoch 8/15
# 16/16 [==============================] - 1s 63ms/step - loss: 1.2077 - accuracy: 0.3680 - val_loss: 1.0891 - val_accuracy: 0.3800
# Epoch 9/15
# 16/16 [==============================] - 1s 64ms/step - loss: 1.2044 - accuracy: 0.3720 - val_loss: 1.0912 - val_accuracy: 0.3800
# Epoch 10/15
# 16/16 [==============================] - 1s 64ms/step - loss: 1.2543 - accuracy: 0.3460 - val_loss: 1.0845 - val_accuracy: 0.3800
# Epoch 11/15
# 16/16 [==============================] - 1s 64ms/step - loss: 1.2063 - accuracy: 0.3600 - val_loss: 1.0905 - val_accuracy: 0.3800
# Epoch 12/15
# 16/16 [==============================] - 1s 65ms/step - loss: 1.1941 - accuracy: 0.3500 - val_loss: 1.0800 - val_accuracy: 0.3800
# Epoch 13/15
# 16/16 [==============================] - 1s 66ms/step - loss: 1.1820 - accuracy: 0.3740 - val_loss: 1.0830 - val_accuracy: 0.3800
# Epoch 14/15
# 16/16 [==============================] - 1s 65ms/step - loss: 1.1889 - accuracy: 0.3560 - val_loss: 1.0965 - val_accuracy: 0.3800
# Epoch 15/15
# 16/16 [==============================] - 1s 65ms/step - loss: 1.1871 - accuracy: 0.3460 - val_loss: 1.0866 - val_accuracy: 0.3800
# 13/13 [==============================] - 1s 16ms/step
# Macro F1-Score for 7 layer(s): 0.1827
# 1 Layer(s): Macro F1-Score = 0.4092
# 3 Layer(s): Macro F1-Score = 0.3571
# 7 Layer(s): Macro F1-Score = 0.1827

# %% [markdown]
# ## Experiment 2: Pengaruh Banyak Cell RNN per Layer

# %%
cell_variations = [32, 64, 128]
cell_results = {}
cell_histories = []
cell_labels = []

for num_cells in cell_variations:
    print(f"\nTraining model with {num_cells} cells per layer...")

    model = create_rnn_model(num_layers=2, units_per_layer=num_cells)
    print(f"Model summary for {num_cells} cells:")
    model.summary()
    
    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    cell_results[num_cells] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    cell_histories.append(history)
    cell_labels.append(f'{num_cells} Cells')
    
    print(f"Macro F1-Score for {num_cells} cells: {macro_f1:.4f}")

plot_training_history(cell_histories, cell_labels, "Effect of Number of RNN Cells per Layer")
for num_cells in cell_variations:
    print(f"{num_cells} Cells: Macro F1-Score = {cell_results[num_cells]['macro_f1']:.4f}")
# Out:
# Training model with 32 cells per layer...
# Model summary for 32 cells:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_11 (SimpleRNN)   (None, 100, 32)           5152
#
#  dropout_11 (Dropout)        (None, 100, 32)           0
#
#  simple_rnn_12 (SimpleRNN)   (None, 32)                2080
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_3 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1,287,331
# Trainable params: 1,287,331
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 42ms/step - loss: 1.1205 - accuracy: 0.3340 - val_loss: 1.0593 - val_accuracy: 0.4300
# Epoch 2/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9738 - accuracy: 0.4960 - val_loss: 1.0574 - val_accuracy: 0.4100
# Epoch 3/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.7809 - accuracy: 0.6880 - val_loss: 1.1662 - val_accuracy: 0.3700
# Epoch 4/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5316 - accuracy: 0.8400 - val_loss: 1.0503 - val_accuracy: 0.5200
# Epoch 5/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3278 - accuracy: 0.9260 - val_loss: 1.0754 - val_accuracy: 0.5000
# Epoch 6/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1640 - accuracy: 0.9860 - val_loss: 1.1253 - val_accuracy: 0.5000
# Epoch 7/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0845 - accuracy: 0.9980 - val_loss: 1.2200 - val_accuracy: 0.5100
# Epoch 8/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 1.2427 - val_accuracy: 0.5200
# Epoch 9/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 1.2631 - val_accuracy: 0.5300
# Epoch 10/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 1.3073 - val_accuracy: 0.5500
# Epoch 11/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 1.3875 - val_accuracy: 0.5200
# Epoch 12/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 1.4043 - val_accuracy: 0.5600
# Epoch 13/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.4025 - val_accuracy: 0.5300
# Epoch 14/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.4675 - val_accuracy: 0.5300
# Epoch 15/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.4673 - val_accuracy: 0.5200
# 13/13 [==============================] - 0s 5ms/step
# Macro F1-Score for 32 cells: 0.4937
#
# Training model with 64 cells per layer...
# Model summary for 64 cells:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_13 (SimpleRNN)   (None, 100, 64)           12352
#
#  dropout_13 (Dropout)        (None, 100, 64)           0
#
#  simple_rnn_14 (SimpleRNN)   (None, 64)                8256
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_4 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,300,803
# Trainable params: 1,300,803
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 40ms/step - loss: 1.1898 - accuracy: 0.3500 - val_loss: 1.1782 - val_accuracy: 0.2400
# Epoch 2/15
# 16/16 [==============================] - 0s 28ms/step - loss: 1.0208 - accuracy: 0.4860 - val_loss: 1.2855 - val_accuracy: 0.3300
# Epoch 3/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8245 - accuracy: 0.6480 - val_loss: 1.1650 - val_accuracy: 0.4200
# Epoch 4/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.5965 - accuracy: 0.7840 - val_loss: 1.5291 - val_accuracy: 0.3300
# Epoch 5/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2677 - accuracy: 0.9340 - val_loss: 1.5482 - val_accuracy: 0.3700
# Epoch 6/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0999 - accuracy: 0.9860 - val_loss: 1.6130 - val_accuracy: 0.3700
# Epoch 7/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.8784 - val_accuracy: 0.3700
# Epoch 8/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 2.0293 - val_accuracy: 0.3800
# Epoch 9/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.9780 - val_accuracy: 0.4000
# Epoch 10/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 2.1254 - val_accuracy: 0.3500
# Epoch 11/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 2.0857 - val_accuracy: 0.3800
# Epoch 12/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 2.1072 - val_accuracy: 0.3800
# Epoch 13/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.1921 - val_accuracy: 0.3700
# Epoch 14/15
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.2144 - val_accuracy: 0.3700
# Epoch 15/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.2342 - val_accuracy: 0.3700
# 13/13 [==============================] - 0s 6ms/step
# Macro F1-Score for 64 cells: 0.4614
#
# Training model with 128 cells per layer...
# Model summary for 128 cells:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_15 (SimpleRNN)   (None, 100, 128)          32896
#
#  dropout_15 (Dropout)        (None, 100, 128)          0
#
#  simple_rnn_16 (SimpleRNN)   (None, 128)               32896
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,346,179
# Trainable params: 1,346,179
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 55ms/step - loss: 1.1677 - accuracy: 0.3700 - val_loss: 1.0695 - val_accuracy: 0.4300
# Epoch 2/15
# 16/16 [==============================] - 1s 43ms/step - loss: 1.2788 - accuracy: 0.3540 - val_loss: 1.2404 - val_accuracy: 0.4400
# Epoch 3/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.2581 - accuracy: 0.3580 - val_loss: 1.1475 - val_accuracy: 0.2800
# Epoch 4/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.2796 - accuracy: 0.3440 - val_loss: 1.1016 - val_accuracy: 0.3700
# Epoch 5/15
# 16/16 [==============================] - 1s 43ms/step - loss: 1.2158 - accuracy: 0.3520 - val_loss: 1.0945 - val_accuracy: 0.3800
# Epoch 6/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.1990 - accuracy: 0.3780 - val_loss: 1.0954 - val_accuracy: 0.3800
# Epoch 7/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.2350 - accuracy: 0.3680 - val_loss: 1.1155 - val_accuracy: 0.3800
# Epoch 8/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.2211 - accuracy: 0.3340 - val_loss: 1.0944 - val_accuracy: 0.3800
# Epoch 9/15
# 16/16 [==============================] - 1s 42ms/step - loss: 1.1833 - accuracy: 0.3220 - val_loss: 1.1081 - val_accuracy: 0.3800
# Epoch 10/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.1260 - accuracy: 0.3880 - val_loss: 1.1340 - val_accuracy: 0.3700
# Epoch 11/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.0151 - accuracy: 0.4980 - val_loss: 1.3038 - val_accuracy: 0.2900
# Epoch 12/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.1049 - accuracy: 0.4440 - val_loss: 1.3505 - val_accuracy: 0.3100
# Epoch 13/15
# 16/16 [==============================] - 1s 41ms/step - loss: 1.2134 - accuracy: 0.4180 - val_loss: 1.6332 - val_accuracy: 0.2800
# Epoch 14/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.3746 - accuracy: 0.3620 - val_loss: 1.1632 - val_accuracy: 0.3700
# Epoch 15/15
# 16/16 [==============================] - 1s 40ms/step - loss: 1.1600 - accuracy: 0.3860 - val_loss: 1.0741 - val_accuracy: 0.4000
# 13/13 [==============================] - 0s 9ms/step
# Macro F1-Score for 128 cells: 0.2657
# 32 Cells: Macro F1-Score = 0.4937
# 64 Cells: Macro F1-Score = 0.4614
# 128 Cells: Macro F1-Score = 0.2657

# %% [markdown]
# ## Experiment 3: Pengaruh Jenis Layer RNN Berdasarkan Arah

# %%
direction_variations = [False, True] 
direction_labels_map = {False: 'Unidirectional', True: 'Bidirectional'}
direction_results = {}
direction_histories = []
direction_labels = []

for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    print(f"\nTraining {direction_name} RNN model...")
    
    model = create_rnn_model(num_layers=2, units_per_layer=64, bidirectional=bidirectional)
    print(f"Model summary for {direction_name} RNN:")
    model.summary()

    history = train_model(model, X_train, y_train, X_valid, y_valid, epochs=15)
    macro_f1, y_pred = evaluate_model(model, X_test, y_test)

    direction_results[bidirectional] = {
        'model': model,
        'history': history,
        'macro_f1': macro_f1,
        'predictions': y_pred
    }
    
    direction_histories.append(history)
    direction_labels.append(direction_name)
    
    print(f"Macro F1-Score for {direction_name}: {macro_f1:.4f}")

plot_training_history(direction_histories, direction_labels, "Effect of RNN Direction")
for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    print(f"{direction_name}: Macro F1-Score = {direction_results[bidirectional]['macro_f1']:.4f}")
# Out:
# Training Unidirectional RNN model...
# Model summary for Unidirectional RNN:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 100, 128)          1280000
#
#  simple_rnn_17 (SimpleRNN)   (None, 100, 64)           12352
#
#  dropout_17 (Dropout)        (None, 100, 64)           0
#
#  simple_rnn_18 (SimpleRNN)   (None, 64)                8256
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_6 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,300,803
# Trainable params: 1,300,803
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 2s 42ms/step - loss: 1.1376 - accuracy: 0.3940 - val_loss: 1.0372 - val_accuracy: 0.4600
# Epoch 2/15
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0684 - accuracy: 0.4600 - val_loss: 0.9309 - val_accuracy: 0.5400
# Epoch 3/15
# 16/16 [==============================] - 0s 28ms/step - loss: 1.0002 - accuracy: 0.4800 - val_loss: 0.8700 - val_accuracy: 0.6100
# Epoch 4/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8544 - accuracy: 0.6120 - val_loss: 1.0089 - val_accuracy: 0.4700
# Epoch 5/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.6523 - accuracy: 0.7300 - val_loss: 1.2107 - val_accuracy: 0.4400
# Epoch 6/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3238 - accuracy: 0.8920 - val_loss: 1.4552 - val_accuracy: 0.4500
# Epoch 7/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1165 - accuracy: 0.9740 - val_loss: 1.8329 - val_accuracy: 0.4500
# Epoch 8/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0459 - accuracy: 0.9980 - val_loss: 1.9014 - val_accuracy: 0.4400
# Epoch 9/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.7078 - val_accuracy: 0.4400
# Epoch 10/15
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.8769 - val_accuracy: 0.4500
# Epoch 11/15
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.8908 - val_accuracy: 0.4500
# Epoch 12/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.9459 - val_accuracy: 0.4500
# Epoch 13/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.9717 - val_accuracy: 0.4400
# Epoch 14/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.9528 - val_accuracy: 0.4400
# Epoch 15/15
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.0261 - val_accuracy: 0.4400
# 13/13 [==============================] - 0s 6ms/step
# Macro F1-Score for Unidirectional: 0.4963
#
# Training Bidirectional RNN model...
# Model summary for Bidirectional RNN:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 100, 128)          1280000
#
#  bidirectional (Bidirectiona  (None, 100, 128)         24704
#  l)
#
#  dropout_19 (Dropout)        (None, 100, 128)          0
#
#  bidirectional_1 (Bidirectio  (None, 128)              24704
#  nal)
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,329,795
# Trainable params: 1,329,795
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 16/16 [==============================] - 3s 67ms/step - loss: 1.1474 - accuracy: 0.3740 - val_loss: 1.0845 - val_accuracy: 0.4300
# Epoch 2/15
# 16/16 [==============================] - 1s 45ms/step - loss: 0.8826 - accuracy: 0.5860 - val_loss: 1.2130 - val_accuracy: 0.4500
# Epoch 3/15
# 16/16 [==============================] - 1s 46ms/step - loss: 0.4662 - accuracy: 0.8480 - val_loss: 1.2419 - val_accuracy: 0.5100
# Epoch 4/15
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1952 - accuracy: 0.9600 - val_loss: 1.4277 - val_accuracy: 0.4600
# Epoch 5/15
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0662 - accuracy: 0.9860 - val_loss: 1.3674 - val_accuracy: 0.4600
# Epoch 6/15
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0187 - accuracy: 0.9980 - val_loss: 1.5237 - val_accuracy: 0.5100
# Epoch 7/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7156 - val_accuracy: 0.5100
# Epoch 8/15
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.6533 - val_accuracy: 0.5500
# Epoch 9/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.7321 - val_accuracy: 0.5300
# Epoch 10/15
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.7038 - val_accuracy: 0.5500
# Epoch 11/15
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.7321 - val_accuracy: 0.5500
# Epoch 12/15
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.7391 - val_accuracy: 0.5400
# Epoch 13/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7667 - val_accuracy: 0.5500
# Epoch 14/15
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.7886 - val_accuracy: 0.5300
# Epoch 15/15
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.8069 - val_accuracy: 0.5400
# 13/13 [==============================] - 0s 11ms/step
# Macro F1-Score for Bidirectional: 0.5270
# Unidirectional: Macro F1-Score = 0.4963
# Bidirectional: Macro F1-Score = 0.5270

# %% [markdown]
# ## Summary

# %%
print("\n1. PENGARUH JUMLAH LAYER RNN:")
best_layers = max(layer_results.keys(), key=lambda x: layer_results[x]['macro_f1'])
for num_layers in layer_variations:
    f1_score = layer_results[num_layers]['macro_f1']
    print(f"   {num_layers} Layer(s): {f1_score:.4f}" + (" -- BEST" if num_layers == best_layers else ""))

print("\n2. PENGARUH BANYAK CELL RNN PER LAYER:")
best_cells = max(cell_results.keys(), key=lambda x: cell_results[x]['macro_f1'])
for num_cells in cell_variations:
    f1_score = cell_results[num_cells]['macro_f1']
    print(f"   {num_cells} Cells: {f1_score:.4f}" + (" -- BEST" if num_cells == best_cells else ""))

print("\n3. PENGARUH JENIS LAYER RNN BERDASARKAN ARAH:")
best_direction = max(direction_results.keys(), key=lambda x: direction_results[x]['macro_f1'])
for bidirectional in direction_variations:
    direction_name = direction_labels_map[bidirectional]
    f1_score = direction_results[bidirectional]['macro_f1']
    print(f"   {direction_name}: {f1_score:.4f}" + (" -- BEST" if bidirectional == best_direction else ""))
# Out:
# 1. PENGARUH JUMLAH LAYER RNN:
#    1 Layer(s): 0.4092 -- BEST
#    3 Layer(s): 0.3571
#    7 Layer(s): 0.1827
#
# 2. PENGARUH BANYAK CELL RNN PER LAYER:
#    32 Cells: 0.4937 -- BEST
#    64 Cells: 0.4614
#    128 Cells: 0.2657
#
# 3. PENGARUH JENIS LAYER RNN BERDASARKAN ARAH:
#    Unidirectional: 0.4963
#    Bidirectional: 0.5270 -- BEST
